# %%
# ==========================
# 5. PLOT BAR CHART (LIKE SLIDE)
# ==========================
stocks = price_cols
x = np.arange(len(stocks))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 4))

# Bars for return and stdev
bars_return = ax.bar(x - width/2, mean_annual.values, width, label='Return')
bars_std    = ax.bar(x + width/2, std_annual.values, width, label='Std Dev')

# X-axis labels
ax.set_xticks(x)
ax.set_xticklabels(stocks)
ax.set_ylabel("Annualised Value")
ax.set_title("Return & Standard Deviation of Shares")
ax.legend()

# Add percentage labels above bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f"{height*100:.2f}%",
                    xy=(bar.get_x() + bar.get_width()/2, height),
                    xytext=(0, 3),  # vertical offset
                    textcoords="offset points",
                    ha="center", va="bottom", fontsize=8)

add_labels(bars_return)
add_labels(bars_std)

plt.tight_layout()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Generates many portfolios that:
#
# Are long-only
#
# Fully invested (weights sum to 1)
#
# For each:
#
# Computes return, volatility, Sharpe ratio
#
# This approximates the cloud of feasible portfolios in MPT.
#
#
# ---
#
# Min-Variance: find portfolio with lowest volatility among the random ones:
#
# ---
# Max-Sharpe: find portfolio with highest Sharpe:
